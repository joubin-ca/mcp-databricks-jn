-- %%
CREATE TABLE mcp_002.default.Contractors (
    ContractorID   BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
    ContractorName STRING NOT NULL,
    ContactEmail   STRING,
    ContactPhone   STRING,
    IsActive       BOOLEAN
);

INSERT INTO mcp_002.default.Contractors (ContractorName, ContactEmail, ContactPhone, IsActive)
VALUES
  ('Acme Construction', 'contact@acme.com', '555-123-4567', TRUE),
  ('Global Builders Ltd.', 'info@globalbuilders.com', '555-987-6543', TRUE),
  ('Skyline Engineering', 'support@skylineeng.com', NULL, FALSE);

SELECT * FROM mcp_002.default.Contractors;
