-- %%
-- Use your actual catalog.schema; using mpc_002.default to match your earlier examples
CREATE TABLE mcp_002.default.Contracts (
  ContractID    BIGINT  GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
  ContractorID  INT  NOT NULL,
  ContractCode  VARCHAR(50) NOT NULL,     -- cannot mark UNIQUE in UC
  Title         STRING NOT NULL,          -- NVARCHAR -> STRING
  AwardDate     DATE   NOT NULL,
  TotalValue    DECIMAL(18,2),
  Currency      CHAR(3),
  Status        STRING NOT NULL
);
--

INSERT INTO mcp_002.default.Contracts
  (ContractorID, ContractCode, Title, AwardDate, TotalValue, Currency, Status)
VALUES
  (1, 'C-1001', 'Highway Expansion Project', DATE'2024-04-15', 1500000.00, 'USD', 'Active'),
  (2, 'C-1002', 'Downtown Office Tower', DATE'2024-06-01', 25000000.00, 'CAD', 'Planned'),
  (3, 'C-1003', 'Bridge Renovation', DATE'2024-07-10', 800000.00, 'USD', 'OnHold'),
  (1, 'C-1004', 'Airport Terminal Upgrade', DATE'2024-08-20', 12000000.00, 'EUR', 'Closed');

INSERT INTO mcp_002.default.Contracts
  (ContractorID, ContractCode, Title, AwardDate, TotalValue, Currency, Status)
VALUES
  (1, 'C-1005', 'Highway 403 Expansion', DATE'2025-10-15', 1500000.00, 'CAD', 'Planned'),
  (2, 'C-1006', 'Markham Office Tower', DATE'2026-06-01', 25000000.00, 'CAD', 'OnHold'),
  (3, 'C-1007', 'Burlington Bridge Renovation', DATE'2025-07-10', 800000.00, 'USD', 'OnHold'),
  (1, 'C-1008', 'Airport Terminal Reno', DATE'2024-08-20', 12000000.00, 'CAD', 'Closed');

SELECT * FROM mcp_002.default.Contracts
