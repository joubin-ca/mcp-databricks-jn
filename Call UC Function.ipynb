# %%
from pyspark.sql import functions as F

# Call a scalar function in Unity Catalog
# df = spark.range(1, 5).selectExpr("mcp_002.default.add_ten(1) as result")
# df.show()

spark.sql("USE CATALOG mcp_002")

# Or using SQL directly
df = spark.sql("SELECT * FROM mcp_002.default.fn_search_contracts('', NULL, 0, NULL)")
# df = spark.sql("SELECT * FROM mcp_002.default.fn_orphan_contracts()")
# df = spark.sql("SELECT * FROM mcp_002.default.fn_total_contract_value_by_contractor_and_status('Acme Construction', 'closed')")
display(df)

# Set the current catalog to 'samples'
# spark.sql("SHOW FUNCTIONS IN default").show()

#
